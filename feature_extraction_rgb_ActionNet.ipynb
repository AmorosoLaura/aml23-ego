# %%
# %%bash
#
# splits=("test" "train")
# num_frames=(5 10 25)
# dense_sampling=("True" "False")
#
# for split in ${splits[@]}
# do
#   for frames in ${num_frames[@]}
#   do
#     for sampling in ${dense_sampling[@]}
#     do
#       python3 save_feat_action_net.py \
#         config=configs/I3D_save_feat_an.yaml \
#         split=$split \
#         save.num_frames_per_clip.RGB=$frames \
#         save.dense_sampling.RGB=$sampling
#     done
#   done
# done
# Out:
# 2024-04-27 13:39:30 LOG INFO Feature Extraction
# 2024-04-27 13:39:30 LOG INFO Running with parameters:
#   action: save
#   name: features_rgb
#   modality: ['RGB']
#   total_batch: 128
#   batch_size: 32
#   gpus: None
#   wandb_name: None
#   resume_from: ./saved_models/I3D_SourceOnlyD1
#   logname: save_D1-S04.log
#   models_dir: models
#   aggregation: True
#   train:
#     num_iter: 5000
#     lr_steps: 3000
#     eval_freq: 50
#     num_clips: 5
#     dense_sampling:
#       RGB: True
#     num_frames_per_clip:
#       RGB: 5
#   test:
#     num_clips: 5
#     dense_sampling:
#       RGB: True
#     num_frames_per_clip:
#       RGB: 5
#   dataset:
#     annotations_path: action_net_annotations_training
#     shift: D1-S04
#     workers: 4
#     stride: 2
#     resolution: 224
#     num_classes: 8
#     RGB:
#       data_path: action-net/frames
#       tmpl: frame_{:010d}.jpg
#       features_name: saved_features
#     Event:
#       rgb4e: 6
#   models:
#     RGB:
#       model: I3D
#       normalize: False
#       kwargs:
#       lr_steps: 3000
#       lr: 0.01
#       sgd_momentum: 0.9
#       weight_decay: 1e-07
#       dropout: 0.5
#       resolution: 224
#       weight_i3d_rgb: ./pretrained_i3d/rgb_imagenet.pt
#   split: test
#   features_path: ['saved_features_action_net']
#   save:
#     num_clips: 5
#     dense_sampling:
#       RGB: True
#     num_frames_per_clip:
#       RGB: 5
#   config: configs/I3D_save_feat_an.yaml
#   experiment_dir: features_rgb/Apr27_13-39-29
#   log_dir: TEST_RESULTS/features_rgb
#   logfile: TEST_RESULTS/features_rgb/save_D1-S04.log
# 2024-04-27 13:39:30 LOG INFO Instantiating models per modality
# 2024-04-27 13:39:30 LOG INFO I3D Net	Modality: RGB
# 2024-04-27 13:39:30 LOG INFO Loading Kinetics weights I3D
# 2024-04-27 13:39:30 LOG INFO  * Skipping Logits weight for 'logits.conv3d.weight'
# 2024-04-27 13:39:30 LOG INFO  * Skipping Logits weight for 'logits.conv3d.bias'
# 2024-04-27 13:39:30 LOG INFO Restoring action-classifier for modality RGB from saved_models/I3D_SourceOnlyD1/Oct25_22-38-50/action-classifier_RGB_9.pth
# 2024-04-27 13:39:30 LOG INFO RGB-Model for action-classifier restored at iter 4850.0
# Best accuracy on val: 59.54 at iter 4000.0
# Last accuracy on val: 58.85
# Last loss: 0.00
# 2024-04-27 13:39:30 LOG INFO Dataloader for S04-test with 81 samples generated
# 2024-04-27 13:40:35 LOG INFO Feature Extraction
# 2024-04-27 13:40:35 LOG INFO Running with parameters:
#   action: save
#   name: features_rgb
#   modality: ['RGB']
#   total_batch: 128
#   batch_size: 32
#   gpus: None
#   wandb_name: None
#   resume_from: ./saved_models/I3D_SourceOnlyD1
#   logname: save_D1-S04.log
#   models_dir: models
#   aggregation: True
#   train:
#     num_iter: 5000
#     lr_steps: 3000
#     eval_freq: 50
#     num_clips: 5
#     dense_sampling:
#       RGB: True
#     num_frames_per_clip:
#       RGB: 5
#   test:
#     num_clips: 5
#     dense_sampling:
#       RGB: True
#     num_frames_per_clip:
#       RGB: 5
#   dataset:
#     annotations_path: action_net_annotations_training
#     shift: D1-S04
#     workers: 4
#     stride: 2
#     resolution: 224
#     num_classes: 8
#     RGB:
#       data_path: action-net/frames
#       tmpl: frame_{:010d}.jpg
#       features_name: saved_features
#     Event:
#       rgb4e: 6
#   models:
#     RGB:
#       model: I3D
#       normalize: False
#       kwargs:
#       lr_steps: 3000
#       lr: 0.01
#       sgd_momentum: 0.9
#       weight_decay: 1e-07
#       dropout: 0.5
#       resolution: 224
#       weight_i3d_rgb: ./pretrained_i3d/rgb_imagenet.pt
#   split: test
#   features_path: ['saved_features_action_net']
#   save:
#     num_clips: 5
#     dense_sampling:
#       RGB: False
#     num_frames_per_clip:
#       RGB: 5
#   config: configs/I3D_save_feat_an.yaml
#   experiment_dir: features_rgb/Apr27_13-40-34
#   log_dir: TEST_RESULTS/features_rgb
#   logfile: TEST_RESULTS/features_rgb/save_D1-S04.log
# 2024-04-27 13:40:35 LOG INFO Instantiating models per modality
# 2024-04-27 13:40:35 LOG INFO I3D Net	Modality: RGB
# 2024-04-27 13:40:35 LOG INFO Loading Kinetics weights I3D
# 2024-04-27 13:40:35 LOG INFO  * Skipping Logits weight for 'logits.conv3d.weight'
# 2024-04-27 13:40:35 LOG INFO  * Skipping Logits weight for 'logits.conv3d.bias'
# 2024-04-27 13:40:35 LOG INFO Restoring action-classifier for modality RGB from saved_models/I3D_SourceOnlyD1/Oct25_22-38-50/action-classifier_RGB_9.pth
# 2024-04-27 13:40:35 LOG INFO RGB-Model for action-classifier restored at iter 4850.0
# Best accuracy on val: 59.54 at iter 4000.0
# Last accuracy on val: 58.85
# Last loss: 0.00
# 2024-04-27 13:40:35 LOG INFO Dataloader for S04-test with 81 samples generated
# 2024-04-27 13:41:37 LOG INFO Feature Extraction
# 2024-04-27 13:41:37 LOG INFO Running with parameters:
#   action: save
#   name: features_rgb
#   modality: ['RGB']
#   total_batch: 128
#   batch_size: 32
#   gpus: None
#   wandb_name: None
#   resume_from: ./saved_models/I3D_SourceOnlyD1
#   logname: save_D1-S04.log
#   models_dir: models
#   aggregation: True
#   train:
#     num_iter: 5000
#     lr_steps: 3000
#     eval_freq: 50
#     num_clips: 5
#     dense_sampling:
#       RGB: True
#     num_frames_per_clip:
#       RGB: 5
#   test:
#     num_clips: 5
#     dense_sampling:
#       RGB: True
#     num_frames_per_clip:
#       RGB: 5
#   dataset:
#     annotations_path: action_net_annotations_training
#     shift: D1-S04
#     workers: 4
#     stride: 2
#     resolution: 224
#     num_classes: 8
#     RGB:
#       data_path: action-net/frames
#       tmpl: frame_{:010d}.jpg
#       features_name: saved_features
#     Event:
#       rgb4e: 6
#   models:
#     RGB:
#       model: I3D
#       normalize: False
#       kwargs:
#       lr_steps: 3000
#       lr: 0.01
#       sgd_momentum: 0.9
#       weight_decay: 1e-07
#       dropout: 0.5
#       resolution: 224
#       weight_i3d_rgb: ./pretrained_i3d/rgb_imagenet.pt
#   split: test
#   features_path: ['saved_features_action_net']
#   save:
#     num_clips: 5
#     dense_sampling:
#       RGB: True
#     num_frames_per_clip:
#       RGB: 10
#   config: configs/I3D_save_feat_an.yaml
#   experiment_dir: features_rgb/Apr27_13-41-35
#   log_dir: TEST_RESULTS/features_rgb
#   logfile: TEST_RESULTS/features_rgb/save_D1-S04.log
# 2024-04-27 13:41:37 LOG INFO Instantiating models per modality
# 2024-04-27 13:41:37 LOG INFO I3D Net	Modality: RGB
# 2024-04-27 13:41:37 LOG INFO Loading Kinetics weights I3D
# 2024-04-27 13:41:37 LOG INFO  * Skipping Logits weight for 'logits.conv3d.weight'
# 2024-04-27 13:41:37 LOG INFO  * Skipping Logits weight for 'logits.conv3d.bias'
# 2024-04-27 13:41:37 LOG INFO Restoring action-classifier for modality RGB from saved_models/I3D_SourceOnlyD1/Oct25_22-38-50/action-classifier_RGB_9.pth
# 2024-04-27 13:41:37 LOG INFO RGB-Model for action-classifier restored at iter 4850.0
# Best accuracy on val: 59.54 at iter 4000.0
# Last accuracy on val: 58.85
# Last loss: 0.00
# 2024-04-27 13:41:37 LOG INFO Dataloader for S04-test with 81 samples generated
# 2024-04-27 13:42:54 LOG INFO Feature Extraction
# 2024-04-27 13:42:54 LOG INFO Running with parameters:
#   action: save
#   name: features_rgb
#   modality: ['RGB']
#   total_batch: 128
#   batch_size: 32
#   gpus: None
#   wandb_name: None
#   resume_from: ./saved_models/I3D_SourceOnlyD1
#   logname: save_D1-S04.log
#   models_dir: models
#   aggregation: True
#   train:
#     num_iter: 5000
#     lr_steps: 3000
#     eval_freq: 50
#     num_clips: 5
#     dense_sampling:
#       RGB: True
#     num_frames_per_clip:
#       RGB: 5
#   test:
#     num_clips: 5
#     dense_sampling:
#       RGB: True
#     num_frames_per_clip:
#       RGB: 5
#   dataset:
#     annotations_path: action_net_annotations_training
#     shift: D1-S04
#     workers: 4
#     stride: 2
#     resolution: 224
#     num_classes: 8
#     RGB:
#       data_path: action-net/frames
#       tmpl: frame_{:010d}.jpg
#       features_name: saved_features
#     Event:
#       rgb4e: 6
#   models:
#     RGB:
#       model: I3D
#       normalize: False
#       kwargs:
#       lr_steps: 3000
#       lr: 0.01
#       sgd_momentum: 0.9
#       weight_decay: 1e-07
#       dropout: 0.5
#       resolution: 224
#       weight_i3d_rgb: ./pretrained_i3d/rgb_imagenet.pt
#   split: test
#   features_path: ['saved_features_action_net']
#   save:
#     num_clips: 5
#     dense_sampling:
#       RGB: False
#     num_frames_per_clip:
#       RGB: 10
#   config: configs/I3D_save_feat_an.yaml
#   experiment_dir: features_rgb/Apr27_13-42-53
#   log_dir: TEST_RESULTS/features_rgb
#   logfile: TEST_RESULTS/features_rgb/save_D1-S04.log
# 2024-04-27 13:42:54 LOG INFO Instantiating models per modality
# 2024-04-27 13:42:54 LOG INFO I3D Net	Modality: RGB
# 2024-04-27 13:42:54 LOG INFO Loading Kinetics weights I3D
# 2024-04-27 13:42:54 LOG INFO  * Skipping Logits weight for 'logits.conv3d.weight'
# 2024-04-27 13:42:54 LOG INFO  * Skipping Logits weight for 'logits.conv3d.bias'
# 2024-04-27 13:42:54 LOG INFO Restoring action-classifier for modality RGB from saved_models/I3D_SourceOnlyD1/Oct25_22-38-50/action-classifier_RGB_9.pth
# 2024-04-27 13:42:54 LOG INFO RGB-Model for action-classifier restored at iter 4850.0
# Best accuracy on val: 59.54 at iter 4000.0
# Last accuracy on val: 58.85
# Last loss: 0.00
# 2024-04-27 13:42:54 LOG INFO Dataloader for S04-test with 81 samples generated
# 2024-04-27 13:44:10 LOG INFO Feature Extraction
# 2024-04-27 13:44:10 LOG INFO Running with parameters:
#   action: save
#   name: features_rgb
#   modality: ['RGB']
#   total_batch: 128
#   batch_size: 32
#   gpus: None
#   wandb_name: None
#   resume_from: ./saved_models/I3D_SourceOnlyD1
#   logname: save_D1-S04.log
#   models_dir: models
#   aggregation: True
#   train:
#     num_iter: 5000
#     lr_steps: 3000
#     eval_freq: 50
#     num_clips: 5
#     dense_sampling:
#       RGB: True
#     num_frames_per_clip:
#       RGB: 5
#   test:
#     num_clips: 5
#     dense_sampling:
#       RGB: True
#     num_frames_per_clip:
#       RGB: 5
#   dataset:
#     annotations_path: action_net_annotations_training
#     shift: D1-S04
#     workers: 4
#     stride: 2
#     resolution: 224
#     num_classes: 8
#     RGB:
#       data_path: action-net/frames
#       tmpl: frame_{:010d}.jpg
#       features_name: saved_features
#     Event:
#       rgb4e: 6
#   models:
#     RGB:
#       model: I3D
#       normalize: False
#       kwargs:
#       lr_steps: 3000
#       lr: 0.01
#       sgd_momentum: 0.9
#       weight_decay: 1e-07
#       dropout: 0.5
#       resolution: 224
#       weight_i3d_rgb: ./pretrained_i3d/rgb_imagenet.pt
#   split: test
#   features_path: ['saved_features_action_net']
#   save:
#     num_clips: 5
#     dense_sampling:
#       RGB: True
#     num_frames_per_clip:
#       RGB: 25
#   config: configs/I3D_save_feat_an.yaml
#   experiment_dir: features_rgb/Apr27_13-44-08
#   log_dir: TEST_RESULTS/features_rgb
#   logfile: TEST_RESULTS/features_rgb/save_D1-S04.log
# 2024-04-27 13:44:10 LOG INFO Instantiating models per modality
# 2024-04-27 13:44:10 LOG INFO I3D Net	Modality: RGB
# 2024-04-27 13:44:10 LOG INFO Loading Kinetics weights I3D
# 2024-04-27 13:44:10 LOG INFO  * Skipping Logits weight for 'logits.conv3d.weight'
# 2024-04-27 13:44:10 LOG INFO  * Skipping Logits weight for 'logits.conv3d.bias'
# 2024-04-27 13:44:10 LOG INFO Restoring action-classifier for modality RGB from saved_models/I3D_SourceOnlyD1/Oct25_22-38-50/action-classifier_RGB_9.pth
# 2024-04-27 13:44:10 LOG INFO RGB-Model for action-classifier restored at iter 4850.0
# Best accuracy on val: 59.54 at iter 4000.0
# Last accuracy on val: 58.85
# Last loss: 0.00
# 2024-04-27 13:44:10 LOG INFO Dataloader for S04-test with 81 samples generated
# 2024-04-27 13:46:47 LOG INFO Feature Extraction
# 2024-04-27 13:46:47 LOG INFO Running with parameters:
#   action: save
#   name: features_rgb
#   modality: ['RGB']
#   total_batch: 128
#   batch_size: 32
#   gpus: None
#   wandb_name: None
#   resume_from: ./saved_models/I3D_SourceOnlyD1
#   logname: save_D1-S04.log
#   models_dir: models
#   aggregation: True
#   train:
#     num_iter: 5000
#     lr_steps: 3000
#     eval_freq: 50
#     num_clips: 5
#     dense_sampling:
#       RGB: True
#     num_frames_per_clip:
#       RGB: 5
#   test:
#     num_clips: 5
#     dense_sampling:
#       RGB: True
#     num_frames_per_clip:
#       RGB: 5
#   dataset:
#     annotations_path: action_net_annotations_training
#     shift: D1-S04
#     workers: 4
#     stride: 2
#     resolution: 224
#     num_classes: 8
#     RGB:
#       data_path: action-net/frames
#       tmpl: frame_{:010d}.jpg
#       features_name: saved_features
#     Event:
#       rgb4e: 6
#   models:
#     RGB:
#       model: I3D
#       normalize: False
#       kwargs:
#       lr_steps: 3000
#       lr: 0.01
#       sgd_momentum: 0.9
#       weight_decay: 1e-07
#       dropout: 0.5
#       resolution: 224
#       weight_i3d_rgb: ./pretrained_i3d/rgb_imagenet.pt
#   split: test
#   features_path: ['saved_features_action_net']
#   save:
#     num_clips: 5
#     dense_sampling:
#       RGB: False
#     num_frames_per_clip:
#       RGB: 25
#   config: configs/I3D_save_feat_an.yaml
#   experiment_dir: features_rgb/Apr27_13-46-45
#   log_dir: TEST_RESULTS/features_rgb
#   logfile: TEST_RESULTS/features_rgb/save_D1-S04.log
# 2024-04-27 13:46:47 LOG INFO Instantiating models per modality
# 2024-04-27 13:46:47 LOG INFO I3D Net	Modality: RGB
# 2024-04-27 13:46:47 LOG INFO Loading Kinetics weights I3D
# 2024-04-27 13:46:47 LOG INFO  * Skipping Logits weight for 'logits.conv3d.weight'
# 2024-04-27 13:46:47 LOG INFO  * Skipping Logits weight for 'logits.conv3d.bias'
# 2024-04-27 13:46:47 LOG INFO Restoring action-classifier for modality RGB from saved_models/I3D_SourceOnlyD1/Oct25_22-38-50/action-classifier_RGB_9.pth
# 2024-04-27 13:46:47 LOG INFO RGB-Model for action-classifier restored at iter 4850.0
# Best accuracy on val: 59.54 at iter 4000.0
# Last accuracy on val: 58.85
# Last loss: 0.00
# 2024-04-27 13:46:47 LOG INFO Dataloader for S04-test with 81 samples generated
# 2024-04-27 13:49:24 LOG INFO Feature Extraction
# 2024-04-27 13:49:24 LOG INFO Running with parameters:
#   action: save
#   name: features_rgb
#   modality: ['RGB']
#   total_batch: 128
#   batch_size: 32
#   gpus: None
#   wandb_name: None
#   resume_from: ./saved_models/I3D_SourceOnlyD1
#   logname: save_D1-S04.log
#   models_dir: models
#   aggregation: True
#   train:
#     num_iter: 5000
#     lr_steps: 3000
#     eval_freq: 50
#     num_clips: 5
#     dense_sampling:
#       RGB: True
#     num_frames_per_clip:
#       RGB: 5
#   test:
#     num_clips: 5
#     dense_sampling:
#       RGB: True
#     num_frames_per_clip:
#       RGB: 5
#   dataset:
#     annotations_path: action_net_annotations_training
#     shift: D1-S04
#     workers: 4
#     stride: 2
#     resolution: 224
#     num_classes: 8
#     RGB:
#       data_path: action-net/frames
#       tmpl: frame_{:010d}.jpg
#       features_name: saved_features
#     Event:
#       rgb4e: 6
#   models:
#     RGB:
#       model: I3D
#       normalize: False
#       kwargs:
#       lr_steps: 3000
#       lr: 0.01
#       sgd_momentum: 0.9
#       weight_decay: 1e-07
#       dropout: 0.5
#       resolution: 224
#       weight_i3d_rgb: ./pretrained_i3d/rgb_imagenet.pt
#   split: train
#   features_path: ['saved_features_action_net']
#   save:
#     num_clips: 5
#     dense_sampling:
#       RGB: True
#     num_frames_per_clip:
#       RGB: 5
#   config: configs/I3D_save_feat_an.yaml
#   experiment_dir: features_rgb/Apr27_13-49-22
#   log_dir: TEST_RESULTS/features_rgb
#   logfile: TEST_RESULTS/features_rgb/save_D1-S04.log
# 2024-04-27 13:49:24 LOG INFO Instantiating models per modality
# 2024-04-27 13:49:24 LOG INFO I3D Net	Modality: RGB
# 2024-04-27 13:49:24 LOG INFO Loading Kinetics weights I3D
# 2024-04-27 13:49:24 LOG INFO  * Skipping Logits weight for 'logits.conv3d.weight'
# 2024-04-27 13:49:24 LOG INFO  * Skipping Logits weight for 'logits.conv3d.bias'
# 2024-04-27 13:49:24 LOG INFO Restoring action-classifier for modality RGB from saved_models/I3D_SourceOnlyD1/Oct25_22-38-50/action-classifier_RGB_9.pth
# 2024-04-27 13:49:24 LOG INFO RGB-Model for action-classifier restored at iter 4850.0
# Best accuracy on val: 59.54 at iter 4000.0
# Last accuracy on val: 58.85
# Last loss: 0.00
# 2024-04-27 13:49:24 LOG INFO Dataloader for S04-train with 735 samples generated
# 2024-04-27 14:05:23 LOG INFO Feature Extraction
# 2024-04-27 14:05:23 LOG INFO Running with parameters:
#   action: save
#   name: features_rgb
#   modality: ['RGB']
#   total_batch: 128
#   batch_size: 32
#   gpus: None
#   wandb_name: None
#   resume_from: ./saved_models/I3D_SourceOnlyD1
#   logname: save_D1-S04.log
#   models_dir: models
#   aggregation: True
#   train:
#     num_iter: 5000
#     lr_steps: 3000
#     eval_freq: 50
#     num_clips: 5
#     dense_sampling:
#       RGB: True
#     num_frames_per_clip:
#       RGB: 5
#   test:
#     num_clips: 5
#     dense_sampling:
#       RGB: True
#     num_frames_per_clip:
#       RGB: 5
#   dataset:
#     annotations_path: action_net_annotations_training
#     shift: D1-S04
#     workers: 4
#     stride: 2
#     resolution: 224
#     num_classes: 8
#     RGB:
#       data_path: action-net/frames
#       tmpl: frame_{:010d}.jpg
#       features_name: saved_features
#     Event:
#       rgb4e: 6
#   models:
#     RGB:
#       model: I3D
#       normalize: False
#       kwargs:
#       lr_steps: 3000
#       lr: 0.01
#       sgd_momentum: 0.9
#       weight_decay: 1e-07
#       dropout: 0.5
#       resolution: 224
#       weight_i3d_rgb: ./pretrained_i3d/rgb_imagenet.pt
#   split: train
#   features_path: ['saved_features_action_net']
#   save:
#     num_clips: 5
#     dense_sampling:
#       RGB: False
#     num_frames_per_clip:
#       RGB: 5
#   config: configs/I3D_save_feat_an.yaml
#   experiment_dir: features_rgb/Apr27_14-05-22
#   log_dir: TEST_RESULTS/features_rgb
#   logfile: TEST_RESULTS/features_rgb/save_D1-S04.log
# 2024-04-27 14:05:23 LOG INFO Instantiating models per modality
# 2024-04-27 14:05:23 LOG INFO I3D Net	Modality: RGB
# 2024-04-27 14:05:23 LOG INFO Loading Kinetics weights I3D
# 2024-04-27 14:05:23 LOG INFO  * Skipping Logits weight for 'logits.conv3d.weight'
# 2024-04-27 14:05:23 LOG INFO  * Skipping Logits weight for 'logits.conv3d.bias'
# 2024-04-27 14:05:24 LOG INFO Restoring action-classifier for modality RGB from saved_models/I3D_SourceOnlyD1/Oct25_22-38-50/action-classifier_RGB_9.pth
# 2024-04-27 14:05:24 LOG INFO RGB-Model for action-classifier restored at iter 4850.0
# Best accuracy on val: 59.54 at iter 4000.0
# Last accuracy on val: 58.85
# Last loss: 0.00
# 2024-04-27 14:05:24 LOG INFO Dataloader for S04-train with 735 samples generated
# 2024-04-27 14:16:43 LOG INFO Feature Extraction
# 2024-04-27 14:16:43 LOG INFO Running with parameters:
#   action: save
#   name: features_rgb
#   modality: ['RGB']
#   total_batch: 128
#   batch_size: 32
#   gpus: None
#   wandb_name: None
#   resume_from: ./saved_models/I3D_SourceOnlyD1
#   logname: save_D1-S04.log
#   models_dir: models
#   aggregation: True
#   train:
#     num_iter: 5000
#     lr_steps: 3000
#     eval_freq: 50
#     num_clips: 5
#     dense_sampling:
#       RGB: True
#     num_frames_per_clip:
#       RGB: 5
#   test:
#     num_clips: 5
#     dense_sampling:
#       RGB: True
#     num_frames_per_clip:
#       RGB: 5
#   dataset:
#     annotations_path: action_net_annotations_training
#     shift: D1-S04
#     workers: 4
#     stride: 2
#     resolution: 224
#     num_classes: 8
#     RGB:
#       data_path: action-net/frames
#       tmpl: frame_{:010d}.jpg
#       features_name: saved_features
#     Event:
#       rgb4e: 6
#   models:
#     RGB:
#       model: I3D
#       normalize: False
#       kwargs:
#       lr_steps: 3000
#       lr: 0.01
#       sgd_momentum: 0.9
#       weight_decay: 1e-07
#       dropout: 0.5
#       resolution: 224
#       weight_i3d_rgb: ./pretrained_i3d/rgb_imagenet.pt
#   split: train
#   features_path: ['saved_features_action_net']
#   save:
#     num_clips: 5
#     dense_sampling:
#       RGB: True
#     num_frames_per_clip:
#       RGB: 10
#   config: configs/I3D_save_feat_an.yaml
#   experiment_dir: features_rgb/Apr27_14-16-42
#   log_dir: TEST_RESULTS/features_rgb
#   logfile: TEST_RESULTS/features_rgb/save_D1-S04.log
# 2024-04-27 14:16:43 LOG INFO Instantiating models per modality
# 2024-04-27 14:16:43 LOG INFO I3D Net	Modality: RGB
# 2024-04-27 14:16:43 LOG INFO Loading Kinetics weights I3D
# 2024-04-27 14:16:43 LOG INFO  * Skipping Logits weight for 'logits.conv3d.weight'
# 2024-04-27 14:16:43 LOG INFO  * Skipping Logits weight for 'logits.conv3d.bias'
# 2024-04-27 14:16:43 LOG INFO Restoring action-classifier for modality RGB from saved_models/I3D_SourceOnlyD1/Oct25_22-38-50/action-classifier_RGB_9.pth
# 2024-04-27 14:16:43 LOG INFO RGB-Model for action-classifier restored at iter 4850.0
# Best accuracy on val: 59.54 at iter 4000.0
# Last accuracy on val: 58.85
# Last loss: 0.00
# 2024-04-27 14:16:43 LOG INFO Dataloader for S04-train with 735 samples generated
# 2024-04-27 14:25:27 LOG INFO Feature Extraction
# 2024-04-27 14:25:27 LOG INFO Running with parameters:
#   action: save
#   name: features_rgb
#   modality: ['RGB']
#   total_batch: 128
#   batch_size: 32
#   gpus: None
#   wandb_name: None
#   resume_from: ./saved_models/I3D_SourceOnlyD1
#   logname: save_D1-S04.log
#   models_dir: models
#   aggregation: True
#   train:
#     num_iter: 5000
#     lr_steps: 3000
#     eval_freq: 50
#     num_clips: 5
#     dense_sampling:
#       RGB: True
#     num_frames_per_clip:
#       RGB: 5
#   test:
#     num_clips: 5
#     dense_sampling:
#       RGB: True
#     num_frames_per_clip:
#       RGB: 5
#   dataset:
#     annotations_path: action_net_annotations_training
#     shift: D1-S04
#     workers: 4
#     stride: 2
#     resolution: 224
#     num_classes: 8
#     RGB:
#       data_path: action-net/frames
#       tmpl: frame_{:010d}.jpg
#       features_name: saved_features
#     Event:
#       rgb4e: 6
#   models:
#     RGB:
#       model: I3D
#       normalize: False
#       kwargs:
#       lr_steps: 3000
#       lr: 0.01
#       sgd_momentum: 0.9
#       weight_decay: 1e-07
#       dropout: 0.5
#       resolution: 224
#       weight_i3d_rgb: ./pretrained_i3d/rgb_imagenet.pt
#   split: train
#   features_path: ['saved_features_action_net']
#   save:
#     num_clips: 5
#     dense_sampling:
#       RGB: False
#     num_frames_per_clip:
#       RGB: 10
#   config: configs/I3D_save_feat_an.yaml
#   experiment_dir: features_rgb/Apr27_14-25-25
#   log_dir: TEST_RESULTS/features_rgb
#   logfile: TEST_RESULTS/features_rgb/save_D1-S04.log
# 2024-04-27 14:25:27 LOG INFO Instantiating models per modality
# 2024-04-27 14:25:27 LOG INFO I3D Net	Modality: RGB
# 2024-04-27 14:25:27 LOG INFO Loading Kinetics weights I3D
# 2024-04-27 14:25:27 LOG INFO  * Skipping Logits weight for 'logits.conv3d.weight'
# 2024-04-27 14:25:27 LOG INFO  * Skipping Logits weight for 'logits.conv3d.bias'
# 2024-04-27 14:25:27 LOG INFO Restoring action-classifier for modality RGB from saved_models/I3D_SourceOnlyD1/Oct25_22-38-50/action-classifier_RGB_9.pth
# 2024-04-27 14:25:27 LOG INFO RGB-Model for action-classifier restored at iter 4850.0
# Best accuracy on val: 59.54 at iter 4000.0
# Last accuracy on val: 58.85
# Last loss: 0.00
# 2024-04-27 14:25:27 LOG INFO Dataloader for S04-train with 735 samples generated
# 2024-04-27 14:34:34 LOG INFO Feature Extraction
# 2024-04-27 14:34:34 LOG INFO Running with parameters:
#   action: save
#   name: features_rgb
#   modality: ['RGB']
#   total_batch: 128
#   batch_size: 32
#   gpus: None
#   wandb_name: None
#   resume_from: ./saved_models/I3D_SourceOnlyD1
#   logname: save_D1-S04.log
#   models_dir: models
#   aggregation: True
#   train:
#     num_iter: 5000
#     lr_steps: 3000
#     eval_freq: 50
#     num_clips: 5
#     dense_sampling:
#       RGB: True
#     num_frames_per_clip:
#       RGB: 5
#   test:
#     num_clips: 5
#     dense_sampling:
#       RGB: True
#     num_frames_per_clip:
#       RGB: 5
#   dataset:
#     annotations_path: action_net_annotations_training
#     shift: D1-S04
#     workers: 4
#     stride: 2
#     resolution: 224
#     num_classes: 8
#     RGB:
#       data_path: action-net/frames
#       tmpl: frame_{:010d}.jpg
#       features_name: saved_features
#     Event:
#       rgb4e: 6
#   models:
#     RGB:
#       model: I3D
#       normalize: False
#       kwargs:
#       lr_steps: 3000
#       lr: 0.01
#       sgd_momentum: 0.9
#       weight_decay: 1e-07
#       dropout: 0.5
#       resolution: 224
#       weight_i3d_rgb: ./pretrained_i3d/rgb_imagenet.pt
#   split: train
#   features_path: ['saved_features_action_net']
#   save:
#     num_clips: 5
#     dense_sampling:
#       RGB: True
#     num_frames_per_clip:
#       RGB: 25
#   config: configs/I3D_save_feat_an.yaml
#   experiment_dir: features_rgb/Apr27_14-34-32
#   log_dir: TEST_RESULTS/features_rgb
#   logfile: TEST_RESULTS/features_rgb/save_D1-S04.log
# 2024-04-27 14:34:34 LOG INFO Instantiating models per modality
# 2024-04-27 14:34:34 LOG INFO I3D Net	Modality: RGB
# 2024-04-27 14:34:34 LOG INFO Loading Kinetics weights I3D
# 2024-04-27 14:34:34 LOG INFO  * Skipping Logits weight for 'logits.conv3d.weight'
# 2024-04-27 14:34:34 LOG INFO  * Skipping Logits weight for 'logits.conv3d.bias'
# 2024-04-27 14:34:34 LOG INFO Restoring action-classifier for modality RGB from saved_models/I3D_SourceOnlyD1/Oct25_22-38-50/action-classifier_RGB_9.pth
# 2024-04-27 14:34:34 LOG INFO RGB-Model for action-classifier restored at iter 4850.0
# Best accuracy on val: 59.54 at iter 4000.0
# Last accuracy on val: 58.85
# Last loss: 0.00
# 2024-04-27 14:34:34 LOG INFO Dataloader for S04-train with 735 samples generated
# 2024-04-27 14:54:42 LOG INFO Feature Extraction
# 2024-04-27 14:54:42 LOG INFO Running with parameters:
#   action: save
#   name: features_rgb
#   modality: ['RGB']
#   total_batch: 128
#   batch_size: 32
#   gpus: None
#   wandb_name: None
#   resume_from: ./saved_models/I3D_SourceOnlyD1
#   logname: save_D1-S04.log
#   models_dir: models
#   aggregation: True
#   train:
#     num_iter: 5000
#     lr_steps: 3000
#     eval_freq: 50
#     num_clips: 5
#     dense_sampling:
#       RGB: True
#     num_frames_per_clip:
#       RGB: 5
#   test:
#     num_clips: 5
#     dense_sampling:
#       RGB: True
#     num_frames_per_clip:
#       RGB: 5
#   dataset:
#     annotations_path: action_net_annotations_training
#     shift: D1-S04
#     workers: 4
#     stride: 2
#     resolution: 224
#     num_classes: 8
#     RGB:
#       data_path: action-net/frames
#       tmpl: frame_{:010d}.jpg
#       features_name: saved_features
#     Event:
#       rgb4e: 6
#   models:
#     RGB:
#       model: I3D
#       normalize: False
#       kwargs:
#       lr_steps: 3000
#       lr: 0.01
#       sgd_momentum: 0.9
#       weight_decay: 1e-07
#       dropout: 0.5
#       resolution: 224
#       weight_i3d_rgb: ./pretrained_i3d/rgb_imagenet.pt
#   split: train
#   features_path: ['saved_features_action_net']
#   save:
#     num_clips: 5
#     dense_sampling:
#       RGB: False
#     num_frames_per_clip:
#       RGB: 25
#   config: configs/I3D_save_feat_an.yaml
#   experiment_dir: features_rgb/Apr27_14-54-40
#   log_dir: TEST_RESULTS/features_rgb
#   logfile: TEST_RESULTS/features_rgb/save_D1-S04.log
# 2024-04-27 14:54:42 LOG INFO Instantiating models per modality
# 2024-04-27 14:54:42 LOG INFO I3D Net	Modality: RGB
# 2024-04-27 14:54:42 LOG INFO Loading Kinetics weights I3D
# 2024-04-27 14:54:42 LOG INFO  * Skipping Logits weight for 'logits.conv3d.weight'
# 2024-04-27 14:54:42 LOG INFO  * Skipping Logits weight for 'logits.conv3d.bias'
# 2024-04-27 14:54:42 LOG INFO Restoring action-classifier for modality RGB from saved_models/I3D_SourceOnlyD1/Oct25_22-38-50/action-classifier_RGB_9.pth
# 2024-04-27 14:54:42 LOG INFO RGB-Model for action-classifier restored at iter 4850.0
# Best accuracy on val: 59.54 at iter 4000.0
# Last accuracy on val: 58.85
# Last loss: 0.00
# 2024-04-27 14:54:42 LOG INFO Dataloader for S04-train with 735 samples generated
